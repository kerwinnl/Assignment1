# %% [markdown]
# <a href="https://colab.research.google.com/github/kerwinnl/Assignment1/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# # 1. My lane (or freestyle) and why
#
# ## Refresh / Content Opportunity Scoring
#
# I chose the **Refresh / Content Opportunity Scoring** lane because it focuses on identifying which content pages should be reviewed first based on observable search and engagement signals. Content teams often have limited time and resources, so prioritizing the right pages can make the review process more efficient. This project aims to provide evidence-based, decision-support recommendations rather than relying on assumptions.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# # 2. The question: decision, action, cost of a wrong call
#
# **Research Question**
#
# Which content pages should be prioritized for review based on observed search and engagement metrics?
#
# **Decision**
#
# The project helps determine which pages should be reviewed first for possible content updates or improvements.
#
# **Who acts on it?**
#
# SEO specialists, content managers, and digital marketing teams.
#
# **Cost of a wrong recommendation**
#
# An incorrect recommendation could cause teams to spend time reviewing low-impact pages while higher-priority pages continue losing visibility and traffic. This project is intended to support decisions, not guarantee outcomes.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("content_refresh_anonymized.csv")

print("=" * 60)
print("STARTER DATASET SUMMARY")
print("=" * 60)

print(f"Total content pages : {len(df):,}")
print(f"Total variables     : {len(df.columns)}")

print()

print(f"Average 90-day impressions : {df['impressions_90d'].mean():,.2f}")
print(f"Average 90-day sessions    : {df['sessions_90d'].mean():,.2f}")
print(f"Median Click-Through Rate  : {df['ctr'].median():.3f}")

print()

declining = (df["trend_direction"] == "down").sum()
print(f"Pages currently marked as 'down': {declining:,}")
# Out:
# ...
# STARTER DATASET SUMMARY
# ...
# Total content pages : 30,000
# Total variables     : 44
#
# Average 90-day impressions : 5,200.37
# Average 90-day sessions    : 37.07
# Median Click-Through Rate  : 0.070
#
# Pages currently marked as 'down': 16,262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# # 3. Quick look at the data
#
# The starter dataset contains **30,000 content pages** with multiple search and engagement variables. The average page receives approximately **5,200 impressions** and **37 sessions** over a 90-day period, while the median click-through rate is approximately **0.07**. The dataset also includes pages showing downward trends, making it suitable for studying how observable signals can help prioritize content review decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
